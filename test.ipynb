# %%
import ailia
import cv2

# 모델과 가중치 파일 설정
MODEL_PATH = 'path/to/anomaly_detection.onnx'
WEIGHT_PATH = 'path/to/anomaly_detection.onnx.prototxt'

# Ailia 모델 로드
net = ailia.Net(MODEL_PATH, WEIGHT_PATH, env_id=0)

# 이미지 로드
image_path = 'path/to/your/image.jpg'
img = cv2.imread(image_path)

# 이미지 전처리
# 여기서는 간단한 리사이징과 정규화를 수행합니다. 실제 모델에 맞게 조정할 필요가 있습니다.
img = cv2.resize(img, (224, 224))
img = img / 255.0
img = img.transpose((2, 0, 1))
img = img[np.newaxis, :, :, :]

# 모델 추론
output = net.predict([img])

# 결과 출력
# 이상 탐지 모델의 출력을 해석하는 방법에 따라 다를 수 있습니다.
print("출력 결과:", output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/being/Desktop/[github] workspace/CrowdCounting/test.ipynb 셀 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/being/Desktop/%5Bgithub%5D%20workspace/CrowdCounting/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import ailia
#       <a href='vscode-notebook-cell:/Users/being/Desktop/%5Bgithub%5D%20workspace/CrowdCounting/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import cv2
#       <a href='vscode-notebook-cell:/Users/being/Desktop/%5Bgithub%5D%20workspace/CrowdCounting/test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> # 모델과 가중치 파일 설정
#
# File ~/Library/Python/3.9/lib/python/site-packages/ailia/__init__.py:3
#       1 # reserved
# ----> 3 raise "Please install trial version from https://ailia.jp/ . For more details see https://github.com/axinc-ai/ailia-models/blob/master/TUTORIAL.md ."
#
# ...

# %%
# !wget https://www.python.org/ftp/python/3.6.5/Python-3.6.5.tgz
# !tar xvfz Python-3.6.5.tgz
# !Python-3.6.5/configure
# !make
# !sudo make install
# Out:
# --2023-11-13 03:26:41--  https://www.python.org/ftp/python/3.6.5/Python-3.6.5.tgz
# www.python.org (www.python.org) 해석 중... 146.75.48.223
# 다음으로 연결 중: www.python.org (www.python.org)|146.75.48.223|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 22994617 (22M) [application/octet-stream]
# 저장 위치: `Python-3.6.5.tgz'
#
# Python-3.6.5.tgz    100%[===================>]  21.93M  7.05MB/s    /  3.1s
#
# 2023-11-13 03:26:45 (7.05 MB/s) - `Python-3.6.5.tgz' 저장함 [22994617/22994617]
#
# x Python-3.6.5/
# x Python-3.6.5/Doc/
# x Python-3.6.5/Doc/c-api/
# x Python-3.6.5/Doc/c-api/sys.rst
# x Python-3.6.5/Doc/c-api/conversion.rst
# x Python-3.6.5/Doc/c-api/marshal.rst
# x Python-3.6.5/Doc/c-api/coro.rst
# x Python-3.6.5/Doc/c-api/method.rst
# x Python-3.6.5/Doc/c-api/index.rst
# x Python-3.6.5/Doc/c-api/bytearray.rst
# x Python-3.6.5/Doc/c-api/bytes.rst
# x Python-3.6.5/Doc/c-api/none.rst
# x Python-3.6.5/Doc/c-api/long.rst
# x Python-3.6.5/Doc/c-api/number.rst
# ...

# %%
# !python --version
